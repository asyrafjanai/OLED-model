# %% [markdown]
# # Device parameters based on efficiency
#
# ### 1. Devices more than 50 cd/a

# %%
# import the libraries we're using
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df50 = pd.read_excel('C:\Anaconda3\projects\oled\device_50.xlsx')
df50 = df50.select_dtypes(include = ['float64', 'int64']).iloc[:, 1:]
df50.head()
# Out:
#    homo_HIL  thick_HIL  lumo_HTL1  homo_HTL1  thickness_HTL1  lumo_HTL2  \
# 0       5.2         60        2.4        6.1              40        2.4
# 1       5.2         60        2.4        6.1              40        2.4
# 2       5.2         60        2.4        6.1              40        2.4
# 3       5.2         60        2.4        6.1              40        2.4
# 4       5.2         60        2.4        6.1              40        2.4
#
#    homo_HTL2  thickness_HTL2  lumo_HTL3  homo_HTL3  ...    total ETL  \
# 0        6.1               0        2.4        6.1  ...           35
# 1        6.1               0        2.4        6.1  ...           35
# 2        6.1               0        2.4        6.1  ...           35
# 3        6.1               0        2.4        6.1  ...           35
# 4        6.1               0        2.4        6.1  ...           35
#
#    lumo_ETL1  homo_ETL1  thickness_ETL1  lumo_ETL2  homo_ETL2  thickness_ETL2  \
# ...

# %%
#box plot
data50 = df50.drop(['thick_HIL', 'thickness_HTL1', 'thickness_HTL2', 'thickness_HTL3', 'total_HTL_thickness', 'thickness_EML', 
               'total ETL', 'thickness_ETL2', 'thickness_ETL1','thickness_EIL', 'cd/a', 'dopant_percentage'], axis=1)

data50.describe()
# Out:
#           homo_HIL    lumo_HTL1    homo_HTL1    lumo_HTL2    homo_HTL2  \
# count  1411.000000  1411.000000  1411.000000  1411.000000  1411.000000
# mean      5.206945     2.274033     5.698370     2.274033     5.698370
# std       0.167357     0.168418     0.267807     0.168418     0.267807
# min       5.200000     1.900000     5.100000     1.900000     5.100000
# 25%       5.200000     2.200000     5.700000     2.200000     5.700000
# 50%       5.200000     2.260000     5.700000     2.260000     5.700000
# 75%       5.200000     2.400000     5.800000     2.400000     5.800000
# max       9.700000     2.500000     6.100000     2.500000     6.100000
#
#          lumo_HTL3    homo_HTL3  triplet_HTL     LUMO_EML     HOMO_EML  \
# count  1411.000000  1411.000000  1411.000000  1411.000000  1411.000000
# mean      2.274033     5.698370     2.813494     2.418327     5.894486
# std       0.168418     0.267807     0.179839     0.193495     0.402239
# ...

# %%
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=data50)
plt.xticks(rotation=90,fontsize=12);

# %% [markdown]
# ### 2. Devices 45-50 cd/a

# %%
df45 = pd.read_excel('C:\Anaconda3\projects\oled\device_50.xlsx', sheetname='45-50')
df45 = df45.select_dtypes(include = ['float64', 'int64']).iloc[:, 1:]
df45.head()
# Out:
#    homo_HIL  thick_HIL  lumo_HTL1  homo_HTL1  thickness_HTL1  lumo_HTL2  \
# 0       5.2         60        2.4        6.1              40        2.4
# 1       5.2         60        2.4        6.1              40        2.4
# 2       5.2         60        2.4        6.1              40        2.4
# 3       5.2         60        2.4        6.1              40        2.4
# 4       5.2         60        2.4        6.1              40        2.4
#
#    homo_HTL2  thickness_HTL2  lumo_HTL3  homo_HTL3  ...    total ETL  \
# 0        6.1               0        2.4        6.1  ...           35
# 1        6.1               0        2.4        6.1  ...           35
# 2        6.1               0        2.4        6.1  ...           35
# 3        6.1               0        2.4        6.1  ...           35
# 4        6.1               0        2.4        6.1  ...           35
#
#    lumo_ETL1  homo_ETL1  thickness_ETL1  lumo_ETL2  homo_ETL2  thickness_ETL2  \
# ...

# %%
#describe dataframe
data45 = df45.drop(['thick_HIL', 'thickness_HTL1', 'thickness_HTL2', 'thickness_HTL3', 'total_HTL_thickness', 'thickness_EML', 
               'total ETL', 'thickness_ETL2', 'thickness_ETL1','thickness_EIL', 'cd/a', 'dopant_percentage'], axis=1)

data45.describe()
# Out:
#            homo_HIL     lumo_HTL1     homo_HTL1     lumo_HTL2     homo_HTL2  \
# count  71534.000000  71534.000000  71534.000000  71534.000000  71534.000000
# mean       6.332266      2.301279      5.752234      2.301279      5.752234
# std        1.808857      0.163948      0.297004      0.163948      0.297004
# min        5.200000      1.900000      5.100000      1.900000      5.100000
# 25%        5.200000      2.200000      5.700000      2.200000      5.700000
# 50%        5.200000      2.400000      5.800000      2.400000      5.800000
# 75%        6.100000      2.400000      5.900000      2.400000      5.900000
# max        9.700000      2.500000      6.100000      2.500000      6.100000
#
#           lumo_HTL3     homo_HTL3   triplet_HTL      LUMO_EML      HOMO_EML  \
# count  71534.000000  71534.000000  71534.000000  71534.000000  71534.000000
# mean       2.301279      5.752234      2.801739      2.404244      5.953549
# ...

# %%
# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=data45)
plt.xticks(rotation=90,fontsize=12);

# %% [markdown]
# ### 3. Devices 40-45 cd/a

# %%
df40 = pd.read_excel('C:\Anaconda3\projects\oled\device_50.xlsx', sheetname='40-45')
df40 = df40.select_dtypes(include = ['float64', 'int64']).iloc[:, 1:]
df40.head()
# Out:
#    homo_HIL  thick_HIL  lumo_HTL1  homo_HTL1  thickness_HTL1  lumo_HTL2  \
# 0       5.2         60        2.4        6.1              40        2.4
# 1       5.2         60        2.4        6.1              40        2.4
# 2       5.2         60        2.4        6.1              40        2.4
# 3       5.2         60        2.4        6.1              40        2.4
# 4       5.2         60        2.4        6.1              40        2.4
#
#    homo_HTL2  thickness_HTL2  lumo_HTL3  homo_HTL3  ...    total ETL  \
# 0        6.1               0        2.4        6.1  ...           35
# 1        6.1               0        2.4        6.1  ...           35
# 2        6.1               0        2.4        6.1  ...           35
# 3        6.1               0        2.4        6.1  ...           35
# 4        6.1               0        2.4        6.1  ...           35
#
#    lumo_ETL1  homo_ETL1  thickness_ETL1  lumo_ETL2  homo_ETL2  thickness_ETL2  \
# ...

# %%
#describe dataframe
data40 = df40.drop(['thick_HIL', 'thickness_HTL1', 'thickness_HTL2', 'thickness_HTL3', 'total_HTL_thickness', 'thickness_EML', 
               'total ETL', 'thickness_ETL2', 'thickness_ETL1','thickness_EIL', 'cd/a', 'dopant_percentage'], axis=1)

data40.describe()
# Out:
#             homo_HIL      lumo_HTL1      homo_HTL1      lumo_HTL2  \
# count  116663.000000  116663.000000  116663.000000  116663.000000
# mean        7.079183       2.236439       5.563747       2.236439
# std         2.016648       0.210706       0.310570       0.210706
# min         5.200000       1.900000       5.100000       1.900000
# 25%         5.300000       2.000000       5.200000       2.000000
# 50%         6.100000       2.260000       5.700000       2.260000
# 75%         9.500000       2.400000       5.800000       2.400000
# max         9.700000       2.500000       6.100000       2.500000
#
#            homo_HTL2      lumo_HTL3      homo_HTL3    triplet_HTL  \
# count  116663.000000  116663.000000  116663.000000  116663.000000
# mean        5.563747       2.236439       5.563747       2.744335
# std         0.310570       0.210706       0.310570       0.230862
# min         5.100000       1.900000       5.100000       2.300000
# ...

# %%
# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=data40)
plt.xticks(rotation=90,fontsize=12);

# %% [markdown]
# ### 4. Devices 35-40 cd/a

# %%
df35 = pd.read_pickle('C:/Anaconda3/projects/oled/35-40.pkl')
df35 = df35.select_dtypes(include = ['float64', 'int64']).iloc[:, :]
df35.head()
# Out:
#       homo_HIL  thick_HIL  lumo_HTL1  homo_HTL1  thickness_HTL1  lumo_HTL2  \
# 1040       5.2         60        2.4        6.1              40        2.4
# 1041       5.2         60        2.4        6.1              40        2.4
# 1042       5.2         60        2.4        6.1              40        2.4
# 1043       5.2         60        2.4        6.1              40        2.4
# 1045       5.2         60        2.4        6.1              40        2.4
#
#       homo_HTL2  thickness_HTL2  lumo_HTL3  homo_HTL3  ...    total ETL  \
# 1040        6.1               0        2.4        6.1  ...           35
# 1041        6.1               0        2.4        6.1  ...           35
# 1042        6.1               0        2.4        6.1  ...           35
# 1043        6.1               0        2.4        6.1  ...           35
# 1045        6.1               0        2.4        6.1  ...           35
#
#       lumo_ETL1  homo_ETL1  thickness_ETL1  lumo_ETL2  homo_ETL2  \
# ...

# %%
#describe dataframe
data35 = df35.drop(['thick_HIL', 'thickness_HTL1', 'thickness_HTL2', 'thickness_HTL3', 'total_HTL_thickness', 'thickness_EML', 
               'total ETL', 'thickness_ETL2', 'thickness_ETL1','thickness_EIL', 'cd/a', 'dopant_percentage'], axis=1)

data35.describe()
# Out:
#             homo_HIL      lumo_HTL1      homo_HTL1      lumo_HTL2  \
# count  178696.000000  178696.000000  178696.000000  178696.000000
# mean        6.300866       2.301666       5.750687       2.301666
# std         1.787347       0.160751       0.286194       0.160751
# min         5.200000       1.900000       5.100000       1.900000
# 25%         5.200000       2.200000       5.700000       2.200000
# 50%         5.200000       2.400000       5.800000       2.400000
# 75%         6.100000       2.400000       5.900000       2.400000
# max         9.700000       2.500000       6.100000       2.500000
#
#            homo_HTL2      lumo_HTL3      homo_HTL3    triplet_HTL  \
# count  178696.000000  178696.000000  178696.000000  178696.000000
# mean        5.750687       2.301666       5.750687       2.806000
# std         0.286194       0.160751       0.286194       0.190567
# min         5.100000       1.900000       5.100000       2.300000
# ...

# %%
# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=data35)
plt.xticks(rotation=90,fontsize=12);

# %% [markdown]
# ### 5. Devices 30-35 cd/a

# %%
df30 = pd.read_pickle('C:/Anaconda3/projects/oled/30-35.pkl')
df30 = df30.select_dtypes(include = ['float64', 'int64']).iloc[:, :]
df30.head()
# Out:
#     homo_HIL  thick_HIL  lumo_HTL1  homo_HTL1  thickness_HTL1  lumo_HTL2  \
# 0        5.2         60        2.4        6.1              40        2.4
# 1        5.2         60        2.4        6.1              40        2.4
# 2        5.2         60        2.4        6.1              40        2.4
# 3        5.2         60        2.4        6.1              40        2.4
# 10       5.2         60        2.4        6.1              40        2.4
#
#     homo_HTL2  thickness_HTL2  lumo_HTL3  homo_HTL3  ...    total ETL  \
# 0         6.1               0        2.4        6.1  ...           35
# 1         6.1               0        2.4        6.1  ...           35
# 2         6.1               0        2.4        6.1  ...           35
# 3         6.1               0        2.4        6.1  ...           35
# 10        6.1               0        2.4        6.1  ...           35
#
#     lumo_ETL1  homo_ETL1  thickness_ETL1  lumo_ETL2  homo_ETL2  \
# ...

# %%
#describe dataframe
data30 = df30.drop(['thick_HIL', 'thickness_HTL1', 'thickness_HTL2', 'thickness_HTL3', 'total_HTL_thickness', 'thickness_EML', 
               'total ETL', 'thickness_ETL2', 'thickness_ETL1','thickness_EIL', 'cd/a', 'dopant_percentage'], axis=1)

data30.describe()
# Out:
#             homo_HIL      lumo_HTL1      homo_HTL1      lumo_HTL2  \
# count  435525.000000  435525.000000  435525.000000  435525.000000
# mean        7.048364       2.266992       5.635515       2.266992
# std         2.021538       0.190627       0.303955       0.190627
# min         5.200000       1.900000       5.100000       1.900000
# 25%         5.200000       2.200000       5.500000       2.200000
# 50%         6.100000       2.400000       5.700000       2.400000
# 75%         9.500000       2.400000       5.800000       2.400000
# max         9.700000       2.500000       6.100000       2.500000
#
#            homo_HTL2      lumo_HTL3      homo_HTL3    triplet_HTL  \
# count  435525.000000  435525.000000  435525.000000  435525.000000
# mean        5.635515       2.266992       5.635515       2.767003
# std         0.303955       0.190627       0.303955       0.224331
# min         5.100000       1.900000       5.100000       2.300000
# ...

# %%
# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=data30)
plt.xticks(rotation=90,fontsize=12);

# %% [markdown]
# ### 6. Devices 25-30 cd/a

# %%
df25 = pd.read_pickle('C:/Anaconda3/projects/oled/25-30.pkl')
df25 = df25.select_dtypes(include = ['float64', 'int64']).iloc[:, :]
df25.head()
# Out:
#     homo_HIL  thick_HIL  lumo_HTL1  homo_HTL1  thickness_HTL1  lumo_HTL2  \
# 5        5.2         60        2.4        6.1              40        2.4
# 6        5.2         60        2.4        6.1              40        2.4
# 7        5.2         60        2.4        6.1              40        2.4
# 8        5.2         60        2.4        6.1              40        2.4
# 21       5.2         60        2.4        6.1              40        2.4
#
#     homo_HTL2  thickness_HTL2  lumo_HTL3  homo_HTL3  ...    total ETL  \
# 5         6.1               0        2.4        6.1  ...           35
# 6         6.1               0        2.4        6.1  ...           35
# 7         6.1               0        2.4        6.1  ...           35
# 8         6.1               0        2.4        6.1  ...           35
# 21        6.1               0        2.4        6.1  ...           35
#
#     lumo_ETL1  homo_ETL1  thickness_ETL1  lumo_ETL2  homo_ETL2  \
# ...

# %%
#describe dataframe
data25 = df25.drop(['thick_HIL', 'thickness_HTL1', 'thickness_HTL2', 'thickness_HTL3', 'total_HTL_thickness', 'thickness_EML', 
               'total ETL', 'thickness_ETL2', 'thickness_ETL1','thickness_EIL', 'cd/a', 'dopant_percentage'], axis=1)

data25.describe()
# Out:
#             homo_HIL      lumo_HTL1      homo_HTL1      lumo_HTL2  \
# count  123195.000000  123195.000000  123195.000000  123195.000000
# mean        6.920138       2.158887       5.406456       2.158887
# std         1.979011       0.240628       0.299952       0.240628
# min         5.200000       1.900000       5.100000       1.900000
# 25%         5.300000       1.900000       5.100000       1.900000
# 50%         6.100000       2.000000       5.200000       2.000000
# 75%         9.500000       2.400000       5.700000       2.400000
# max         9.700000       2.500000       6.100000       2.500000
#
#            homo_HTL2      lumo_HTL3      homo_HTL3    triplet_HTL  \
# count  123195.000000  123195.000000  123195.000000  123195.000000
# mean        5.406456       2.158887       5.406456       2.686498
# std         0.299952       0.240628       0.299952       0.225853
# min         5.100000       1.900000       5.100000       2.300000
# ...

# %%
# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=data25)
plt.xticks(rotation=90,fontsize=12);

# %% [markdown]
# ### 7. Devices 20-25 cd/a

# %%
df20 = pd.read_pickle('C:/Anaconda3/projects/oled/20-25.pkl')
df20 = df20.select_dtypes(include = ['float64', 'int64']).iloc[:, :]
df20.head()
# Out:
#        homo_HIL  thick_HIL  lumo_HTL1  homo_HTL1  thickness_HTL1  lumo_HTL2  \
# 48007       5.2         60        1.9        5.1              40        1.9
# 48047       5.2         60        1.9        5.1              40        1.9
# 48052       5.2         60        1.9        5.1              40        1.9
# 48207       5.2         60        1.9        5.1              40        1.9
# 48567       5.2         60        1.9        5.1              40        1.9
#
#        homo_HTL2  thickness_HTL2  lumo_HTL3  homo_HTL3  ...    total ETL  \
# 48007        5.1               0        1.9        5.1  ...           35
# 48047        5.1               0        1.9        5.1  ...           35
# 48052        5.1               0        1.9        5.1  ...           35
# 48207        5.1               0        1.9        5.1  ...           35
# 48567        5.1               0        1.9        5.1  ...           35
#
#        lumo_ETL1  homo_ETL1  thickness_ETL1  lumo_ETL2  homo_ETL2  \
# ...

# %%
#describe dataframe
data20 = df20.drop(['thick_HIL', 'thickness_HTL1', 'thickness_HTL2', 'thickness_HTL3', 'total_HTL_thickness', 'thickness_EML', 
               'total ETL', 'thickness_ETL2', 'thickness_ETL1','thickness_EIL', 'cd/a', 'dopant_percentage'], axis=1)

data20.describe()
# Out:
#           homo_HIL    lumo_HTL1    homo_HTL1    lumo_HTL2    homo_HTL2  \
# count  5856.000000  5856.000000  5856.000000  5856.000000  5856.000000
# mean      6.877971     2.159139     5.253586     2.159139     5.253586
# std       1.842539     0.271576     0.206407     0.271576     0.206407
# min       5.200000     1.900000     5.100000     1.900000     5.100000
# 25%       5.300000     1.900000     5.100000     1.900000     5.100000
# 50%       6.100000     2.000000     5.200000     2.000000     5.200000
# 75%       9.500000     2.500000     5.200000     2.500000     5.200000
# max       9.700000     2.500000     5.900000     2.500000     5.900000
#
#          lumo_HTL3    homo_HTL3  triplet_HTL      LUMO_EML      HOMO_EML  \
# count  5856.000000  5856.000000  5856.000000  5.856000e+03  5.856000e+03
# mean      2.159139     5.253586     2.569397  2.600000e+00  6.100000e+00
# std       0.271576     0.206407     0.218095  2.487112e-13  6.697437e-13
# ...

# %%
# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=data20)
plt.xticks(rotation=90,fontsize=12);

# %% [markdown]
# ### 8. Devices 10-20 cd/a

# %%
df10 = pd.read_pickle('C:/Anaconda3/projects/oled/10-20.pkl')
df10 = df10.select_dtypes(include = ['float64', 'int64']).iloc[:, :]
df10.head()
# Out:
#      homo_HIL  thick_HIL  lumo_HTL1  homo_HTL1  thickness_HTL1  lumo_HTL2  \
# 19        5.2         60        2.4        6.1              40        2.4
# 34        5.2         60        2.4        6.1              40        2.4
# 64        5.2         60        2.4        6.1              40        2.4
# 99        5.2         60        2.4        6.1              40        2.4
# 114       5.2         60        2.4        6.1              40        2.4
#
#      homo_HTL2  thickness_HTL2  lumo_HTL3  homo_HTL3  ...    total ETL  \
# 19         6.1               0        2.4        6.1  ...           35
# 34         6.1               0        2.4        6.1  ...           35
# 64         6.1               0        2.4        6.1  ...           35
# 99         6.1               0        2.4        6.1  ...           35
# 114        6.1               0        2.4        6.1  ...           35
#
#      lumo_ETL1  homo_ETL1  thickness_ETL1  lumo_ETL2  homo_ETL2  \
# ...

# %%
#describe dataframe
data10 = df10.drop(['thick_HIL', 'thickness_HTL1', 'thickness_HTL2', 'thickness_HTL3', 'total_HTL_thickness', 'thickness_EML', 
               'total ETL', 'thickness_ETL2', 'thickness_ETL1','thickness_EIL', 'cd/a', 'dopant_percentage'], axis=1)

data10.describe()
# Out:
#            homo_HIL     lumo_HTL1     homo_HTL1     lumo_HTL2     homo_HTL2  \
# count  32059.000000  32059.000000  32059.000000  32059.000000  32059.000000
# mean       6.722652      2.297863      5.672753      2.297863      5.672753
# std        1.957882      0.180173      0.313660      0.180173      0.313660
# min        5.200000      1.900000      5.100000      1.900000      5.100000
# 25%        5.200000      2.200000      5.500000      2.200000      5.500000
# 50%        5.300000      2.400000      5.700000      2.400000      5.700000
# 75%        9.500000      2.400000      5.900000      2.400000      5.900000
# max        9.700000      2.500000      6.100000      2.500000      6.100000
#
#           lumo_HTL3     homo_HTL3   triplet_HTL      LUMO_EML      HOMO_EML  \
# count  32059.000000  32059.000000  32059.000000  32059.000000  32059.000000
# mean       2.297863      5.672753      2.766622      2.426552      6.816231
# ...

# %%
# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=data10)
plt.xticks(rotation=90,fontsize=12);

# %% [markdown]
# ### 9. Devices below 10 cd/a

# %%
df5 = pd.read_pickle('C:/Anaconda3/projects/oled/0-10.pkl')
df5 = df5.select_dtypes(include = ['float64', 'int64']).iloc[:, :]
df5.head()
# Out:
#     homo_HIL  thick_HIL  lumo_HTL1  homo_HTL1  thickness_HTL1  lumo_HTL2  \
# 15       5.2         60        2.4        6.1              40        2.4
# 16       5.2         60        2.4        6.1              40        2.4
# 17       5.2         60        2.4        6.1              40        2.4
# 18       5.2         60        2.4        6.1              40        2.4
# 30       5.2         60        2.4        6.1              40        2.4
#
#     homo_HTL2  thickness_HTL2  lumo_HTL3  homo_HTL3  ...   total ETL  \
# 15        6.1               0        2.4        6.1  ...          35
# 16        6.1               0        2.4        6.1  ...          35
# 17        6.1               0        2.4        6.1  ...          35
# 18        6.1               0        2.4        6.1  ...          35
# 30        6.1               0        2.4        6.1  ...          35
#
#     lumo_ETL1  homo_ETL1  thickness_ETL1  lumo_ETL2  homo_ETL2  \
# ...

# %%
#describe dataframe
data5 = df5.drop(['thick_HIL', 'thickness_HTL1', 'thickness_HTL2', 'thickness_HTL3', 'total_HTL_thickness', 'thickness_EML', 
               'total ETL', 'thickness_ETL2', 'thickness_ETL1','thickness_EIL', 'cd/a', 'dopant_percentage'], axis=1)

data5.describe()
# Out:
#             homo_HIL      lumo_HTL1      homo_HTL1      lumo_HTL2  \
# count  183221.000000  183221.000000  183221.000000  183221.000000
# mean        6.852700       2.250437       5.616644       2.250437
# std         1.984747       0.201409       0.319403       0.201409
# min         5.200000       1.900000       5.100000       1.900000
# 25%         5.200000       2.000000       5.200000       2.000000
# 50%         6.100000       2.260000       5.700000       2.260000
# 75%         9.500000       2.400000       5.800000       2.400000
# max         9.700000       2.500000       6.100000       2.500000
#
#            homo_HTL2      lumo_HTL3      homo_HTL3    triplet_HTL  \
# count  183221.000000  183221.000000  183221.000000  183221.000000
# mean        5.616644       2.250437       5.616644       2.761779
# std         0.319403       0.201409       0.319403       0.217949
# min         5.100000       1.900000       5.100000       2.300000
# ...

# %%
# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=data5)
plt.xticks(rotation=90,fontsize=12);

# %% [markdown]
# # Comparison of each layer
#
# ## Each layer is compared with the predicted efficiency based on the algorithm
#
# 50 means more than 50cd/a, 45 means 45-50 cd/a and so on. 5 means efficiency lower than 10

# %%
HTL = {'50': df50['lumo_HTL1'] , '45': df45['lumo_HTL1'] , '40': df40['lumo_HTL1'] , '35': df35['lumo_HTL1'] , 
       '30': df30['lumo_HTL1'] , '25': df25['lumo_HTL1'] , '20': df20['lumo_HTL1'] , '10': df10['lumo_HTL1'] , 
       '5': df5['lumo_HTL1']}
sequence = ['50', '45', '40', '35', '30', '25', '20', '10', '5']
df = pd.DataFrame(data=HTL).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.title('HTL LUMO ',fontsize=20);
df.describe()
# Out:
#                 50            45             40             35             30  \
# count  1411.000000  71534.000000  116663.000000  178696.000000  435525.000000
# mean      2.274033      2.301279       2.236439       2.301666       2.266992
# std       0.168418      0.163948       0.210706       0.160751       0.190627
# min       1.900000      1.900000       1.900000       1.900000       1.900000
# 25%       2.200000      2.200000       2.000000       2.200000       2.200000
# 50%       2.260000      2.400000       2.260000       2.400000       2.400000
# 75%       2.400000      2.400000       2.400000       2.400000       2.400000
# max       2.500000      2.500000       2.500000       2.500000       2.500000
#
#                   25           20            10              5
# count  123195.000000  5856.000000  32059.000000  183221.000000
# mean        2.158887     2.159139      2.297863       2.250437
# std         0.240628     0.271576      0.180173       0.201409
# ...

# %%
HTL = {'50': df50['homo_HTL1'] , '45': df45['homo_HTL1'] , '40': df40['homo_HTL1'] , '35': df35['homo_HTL1'] , 
       '30': df30['homo_HTL1'] , '25': df25['homo_HTL1'] , '20': df20['homo_HTL1'] , '10': df10['homo_HTL1'] , 
       '5': df5['homo_HTL1']}
sequence = ['50', '45', '40', '35', '30', '25', '20', '10', '5']
df = pd.DataFrame(data=HTL).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.title('HTL HOMO ',fontsize=20);
df.describe()
# Out:
#                 50            45             40             35             30  \
# count  1411.000000  71534.000000  116663.000000  178696.000000  435525.000000
# mean      5.698370      5.752234       5.563747       5.750687       5.635515
# std       0.267807      0.297004       0.310570       0.286194       0.303955
# min       5.100000      5.100000       5.100000       5.100000       5.100000
# 25%       5.700000      5.700000       5.200000       5.700000       5.500000
# 50%       5.700000      5.800000       5.700000       5.800000       5.700000
# 75%       5.800000      5.900000       5.800000       5.900000       5.800000
# max       6.100000      6.100000       6.100000       6.100000       6.100000
#
#                   25           20            10              5
# count  123195.000000  5856.000000  32059.000000  183221.000000
# mean        5.406456     5.253586      5.672753       5.616644
# std         0.299952     0.206407      0.313660       0.319403
# ...

# %%
HTL = {'50': df50['triplet_HTL'] , '45': df45['triplet_HTL'] , '40': df40['triplet_HTL'] , '35': df35['triplet_HTL'] , 
       '30': df30['triplet_HTL'] , '25': df25['triplet_HTL'] , '20': df20['triplet_HTL'] , '10': df10['triplet_HTL'] , 
       '5': df5['triplet_HTL']}
sequence = ['50', '45', '40', '35', '30', '25', '20', '10', '5']
df = pd.DataFrame(data=HTL).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.title('HTL triplet ',fontsize=20);
df.describe()
# Out:
#                 50            45             40             35             30  \
# count  1411.000000  71534.000000  116663.000000  178696.000000  435525.000000
# mean      2.813494      2.801739       2.744335       2.806000       2.767003
# std       0.179839      0.190650       0.230862       0.190567       0.224331
# min       2.300000      2.300000       2.300000       2.300000       2.300000
# 25%       2.800000      2.670000       2.580000       2.670000       2.580000
# 50%       2.870000      2.800000       2.870000       2.870000       2.870000
# 75%       2.940000      2.940000       2.940000       2.940000       2.940000
# max       3.000000      3.000000       3.000000       3.000000       3.000000
#
#                   25           20            10              5
# count  123195.000000  5856.000000  32059.000000  183221.000000
# mean        2.686498     2.569397      2.766622       2.761779
# std         0.225853     0.218095      0.233054       0.217949
# ...

# %%
ETL = {'50': df50['lumo_ETL1'] , '45': df45['lumo_ETL1'] , '40': df40['lumo_ETL1'] , '35': df35['lumo_ETL1'] , 
       '30': df30['lumo_ETL1'] , '25': df25['lumo_ETL1'] , '20': df20['lumo_ETL1'] , '10': df10['lumo_ETL1'] , 
       '5': df5['lumo_ETL1']}
sequence = ['50', '45', '40', '35', '30', '25', '20', '10', '5']
df = pd.DataFrame(data=ETL).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.title('ETL LUMO ',fontsize=20);
df.describe()
# Out:
#                 50            45             40             35             30  \
# count  1411.000000  71534.000000  116663.000000  178696.000000  435525.000000
# mean      2.601935      2.667003       2.752421       2.676480       2.728187
# std       0.171010      0.255408       0.280277       0.249328       0.280843
# min       2.260000      2.260000       2.260000       2.260000       2.260000
# 25%       2.500000      2.500000       2.520000       2.500000       2.520000
# 50%       2.700000      2.700000       2.730000       2.700000       2.700000
# 75%       2.730000      2.730000       2.910000       2.730000       2.750000
# max       3.320000      3.320000       3.320000       3.320000       3.320000
#
#                   25           20            10              5
# count  123195.000000  5856.000000  32059.000000  183221.000000
# mean        2.787775     2.778519      3.123507       3.095887
# std         0.285965     0.269745      0.299740       0.293254
# ...

# %%
ETL = {'50': df50['homo_ETL1'] , '45': df45['homo_ETL1'] , '40': df40['homo_ETL1'] , '35': df35['homo_ETL1'] , 
       '30': df30['homo_ETL1'] , '25': df25['homo_ETL1'] , '20': df20['homo_ETL1'] , '10': df10['homo_ETL1'] , 
       '5': df5['homo_ETL1']}
sequence = ['50', '45', '40', '35', '30', '25', '20', '10', '5']
df = pd.DataFrame(data=ETL).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.title('ETL HOMO ',fontsize=20);
df.describe()
# Out:
#                 50            45             40             35             30  \
# count  1411.000000  71534.000000  116663.000000  178696.000000  435525.000000
# mean      6.409376      6.492592       6.528627       6.508365       6.520324
# std       0.331640      0.329644       0.311580       0.323348       0.321142
# min       5.850000      5.850000       5.850000       5.850000       5.850000
# 25%       6.130000      6.130000       6.300000       6.300000       6.300000
# 50%       6.500000      6.500000       6.560000       6.560000       6.560000
# 75%       6.790000      6.790000       6.790000       6.800000       6.790000
# max       7.000000      7.000000       7.000000       7.000000       7.000000
#
#                   25           20            10              5
# count  123195.000000  5856.000000  32059.000000  183221.000000
# mean        6.509699     6.522025      6.560591       6.528564
# std         0.302271     0.291168      0.346558       0.338539
# ...

# %%
ETL = {'50': df50['triplet_ETL'] , '45': df45['triplet_ETL'] , '40': df40['triplet_ETL'] , '35': df35['triplet_ETL'] , 
       '30': df30['triplet_ETL'] , '25': df25['triplet_ETL'] , '20': df20['triplet_ETL'] , '10': df10['triplet_ETL'] , 
       '5': df5['triplet_ETL']}
sequence = ['50', '45', '40', '35', '30', '25', '20', '10', '5']
df = pd.DataFrame(data=ETL).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.title('ETL triplet ',fontsize=20);
df.describe()
# Out:
#                 50            45             40             35             30  \
# count  1411.000000  71534.000000  116663.000000  178696.000000  435525.000000
# mean      2.811531      2.860069       2.845887       2.865629       2.851061
# std       0.219356      0.251603       0.230344       0.256014       0.236857
# min       2.690000      2.690000       2.690000       2.690000       2.690000
# 25%       2.700000      2.700000       2.700000       2.700000       2.700000
# 50%       2.740000      2.750000       2.750000       2.750000       2.750000
# 75%       2.760000      2.800000       2.800000       2.800000       2.800000
# max       3.400000      3.400000       3.400000       3.400000       3.400000
#
#                   25           20            10              5
# count  123195.000000  5856.000000  32059.000000  183221.000000
# mean        2.817178     2.830353      2.568043       2.566426
# std         0.196090     0.216460      0.046632       0.047225
# ...

# %%
EML = {'50': df50['LUMO_EML'] , '45': df45['LUMO_EML'] , '40': df40['LUMO_EML'] , '35': df35['LUMO_EML'] , 
       '30': df30['LUMO_EML'] , '25': df25['LUMO_EML'] , '20': df20['LUMO_EML'] , '10': df10['LUMO_EML'] , 
       '5': df5['LUMO_EML']}
sequence = ['50', '45', '40', '35', '30', '25', '20', '10', '5']
df = pd.DataFrame(data=EML).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.title('EML LUMO ',fontsize=20);
df.describe()
# Out:
#                 50            45             40             35             30  \
# count  1411.000000  71534.000000  116663.000000  178696.000000  435525.000000
# mean      2.418327      2.404244       2.402155       2.416794       2.393310
# std       0.193495      0.220394       0.239325       0.220878       0.239231
# min       2.020000      2.020000       2.020000       2.020000       2.020000
# 25%       2.300000      2.300000       2.280000       2.300000       2.280000
# 50%       2.400000      2.400000       2.400000       2.400000       2.390000
# 75%       2.460000      2.460000       2.460000       2.460000       2.460000
# max       3.000000      3.000000       3.000000       3.000000       3.000000
#
#                   25            20            10              5
# count  123195.000000  5.856000e+03  32059.000000  183221.000000
# mean        2.437745  2.600000e+00      2.426552       2.403528
# std         0.212790  2.487112e-13      0.148400       0.242647
# ...

# %%
EML = {'50': df50['HOMO_EML'] , '45': df45['HOMO_EML'] , '40': df40['HOMO_EML'] , '35': df35['HOMO_EML'] , 
       '30': df30['HOMO_EML'] , '25': df25['HOMO_EML'] , '20': df20['HOMO_EML'] , '10': df10['HOMO_EML'] , 
       '5': df5['HOMO_EML']}
sequence = ['50', '45', '40', '35', '30', '25', '20', '10', '5']
df = pd.DataFrame(data=EML).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.title('EML HOMO ',fontsize=20);
df.describe()
# Out:
#                 50            45             40             35             30  \
# count  1411.000000  71534.000000  116663.000000  178696.000000  435525.000000
# mean      5.894486      5.953549       5.953870       5.917963       5.926638
# std       0.402239      0.506062       0.497721       0.464821       0.464822
# min       5.510000      5.510000       5.510000       5.510000       5.510000
# 25%       5.710000      5.710000       5.710000       5.710000       5.710000
# 50%       5.800000      5.800000       5.850000       5.800000       5.800000
# 75%       5.900000      5.900000       5.920000       5.900000       5.900000
# max       7.500000      7.500000       7.500000       7.500000       7.500000
#
#                   25            20            10              5
# count  123195.000000  5.856000e+03  32059.000000  183221.000000
# mean        6.152442  6.100000e+00      6.816231       5.811714
# std         0.613773  6.697437e-13      0.805120       0.169090
# ...

# %%
EML = {'50': df50['triplet_HOST'] , '45': df45['triplet_HOST'] , '40': df40['triplet_HOST'] , '35': df35['triplet_HOST'] , 
       '30': df30['triplet_HOST'] , '25': df25['triplet_HOST'] , '20': df20['triplet_HOST'] , '10': df10['triplet_HOST'] , 
       '5': df5['triplet_HOST']}
sequence = ['50', '45', '40', '35', '30', '25', '20', '10', '5']
df = pd.DataFrame(data=EML).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.title('triplet HOST ',fontsize=20);
df.describe()
# Out:
#                 50            45             40             35             30  \
# count  1411.000000  71534.000000  116663.000000  178696.000000  435525.000000
# mean      2.925124      2.923131       2.893208       2.927612       2.908709
# std       0.071545      0.091582       0.110194       0.092198       0.099381
# min       2.790000      2.640000       2.640000       2.640000       2.640000
# 25%       2.900000      2.860000       2.800000       2.900000       2.840000
# 50%       2.940000      2.930000       2.910000       2.940000       2.910000
# 75%       2.960000      2.960000       2.960000       2.960000       2.960000
# max       3.100000      3.100000       3.100000       3.100000       3.100000
#
#                   25            20            10              5
# count  123195.000000  5.856000e+03  32059.000000  183221.000000
# mean        2.821028  2.710000e+00      2.798038       2.916308
# std         0.124494  4.054881e-13      0.131472       0.093160
# ...
