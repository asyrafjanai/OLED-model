# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %matplotlib inline

df = pd.read_excel('C:/Anaconda3/projects/oled/oled.xlsx', sheetname='pholed_model')
df = df[list(df.columns)[1:-1] + ['cd/A']]
df.dropna(axis=0, inplace=True)

X = df[list(df.columns)[:-1]]
y = df[['cd/A']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25, random_state=12)

# filename = 'adaboost_model.sav'
filename = 'pholed_rf_model.sav'

# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
print('R-squared: ', loaded_model.score(X_test, y_test))
# Out:
# R-squared:  0.87869391923

# %%
new_df = pd.read_pickle('C:/Anaconda3/projects/oled/fix all triplets/generated1.pkl')

new_X = new_df[:]

y_pred = loaded_model.predict(new_X)
y_pred = [round(float(i), 2) for i in y_pred]

new_X['cd/a'] = y_pred
# new_X.head()

triplet3 = new_X.loc[new_X['HOMO_EML'] == 6.2]
# triplet3.head()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_X.iloc[:, 11:23]
# Out:
#        total_HTL_thickness  triplet_HTL  LUMO_EML  HOMO_EML  triplet_HOST  \
# 0                       40         2.85       2.4       6.2             3
# 1                       40         2.85       2.4       6.2             3
# 2                       40         2.85       2.4       6.2             3
# 3                       40         2.85       2.4       6.2             3
# 4                       40         2.85       2.4       6.2             3
# 5                       40         2.85       2.4       6.2             3
# 6                       40         2.85       2.4       6.2             3
# 7                       40         2.85       2.4       6.2             3
# 8                       40         2.85       2.4       6.2             3
# 9                       40         2.85       2.4       6.2             3
# 10                      40         2.85       2.4       6.2             3
# 11                      40         2.85       2.4       6.2             3
# 12                      40         2.85       2.4       6.2             3
# 13                      40         2.85       2.4       6.2             3
# 14                      40         2.85       2.4       6.2             3
# 15                      40         2.85       2.4       6.2             3
# 16                      40         2.85       2.4       6.2             3
# 17                      40         2.85       2.4       6.2             3
# 18                      40         2.85       2.4       6.2             3
# 19                      40         2.85       2.4       6.2             3
# 20                      40         2.85       2.4       6.2             3
# 21                      40         2.85       2.4       6.2             3
# 22                      40         2.85       2.4       6.2             3
# 23                      40         2.85       2.4       6.2             3
# 24                      40         2.85       2.4       6.2             3
# 25                      40         2.85       2.4       6.2             3
# 26                      40         2.85       2.4       6.2             3
# 27                      40         2.85       2.4       6.2             3
# 28                      40         2.85       2.4       6.2             3
# 29                      40         2.85       2.4       6.2             3
# ...                    ...          ...       ...       ...           ...
# 18210                   40         2.85       2.4       5.6             3
# 18211                   40         2.85       2.4       5.6             3
# 18212                   40         2.85       2.4       5.6             3
# 18213                   40         2.85       2.4       5.6             3
# 18214                   40         2.85       2.4       5.6             3
# 18215                   40         2.85       2.4       5.6             3
# 18216                   40         2.85       2.4       5.6             3
# 18217                   40         2.85       2.4       5.6             3
# 18218                   40         2.85       2.4       5.6             3
# 18219                   40         2.85       2.4       5.6             3
# 18220                   40         2.85       2.4       5.6             3
# 18221                   40         2.85       2.4       5.6             3
# 18222                   40         2.85       2.4       5.6             3
# 18223                   40         2.85       2.4       5.6             3
# 18224                   40         2.85       2.4       5.6             3
# 18225                   40         2.85       2.4       5.6             3
# 18226                   40         2.85       2.4       5.6             3
# 18227                   40         2.85       2.4       5.6             3
# 18228                   40         2.85       2.4       5.6             3
# 18229                   40         2.85       2.4       5.6             3
# 18230                   40         2.85       2.4       5.6             3
# 18231                   40         2.85       2.4       5.6             3
# 18232                   40         2.85       2.4       5.6             3
# 18233                   40         2.85       2.4       5.6             3
# 18234                   40         2.85       2.4       5.6             3
# 18235                   40         2.85       2.4       5.6             3
# 18236                   40         2.85       2.4       5.6             3
# 18237                   40         2.85       2.4       5.6             3
# 18238                   40         2.85       2.4       5.6             3
# 18239                   40         2.85       2.4       5.6             3
#
#        thickness_EML  lumo_dopant  homo_dopant  triplet_dopant  \
# 0                 20            3          5.7             2.7
# 1                 20            3          5.7             2.7
# 2                 20            3          5.7             2.7
# 3                 20            3          5.7             2.7
# 4                 20            3          5.7             2.7
# 5                 20            3          5.7             2.7
# 6                 20            3          5.7             2.7
# 7                 20            3          5.7             2.7
# 8                 20            3          5.7             2.7
# 9                 20            3          5.7             2.7
# 10                20            3          5.7             2.7
# 11                20            3          5.7             2.7
# 12                20            3          5.7             2.7
# 13                20            3          5.7             2.7
# 14                20            3          5.7             2.7
# 15                20            3          5.7             2.7
# 16                20            3          5.7             2.7
# 17                20            3          5.7             2.7
# 18                20            3          5.7             2.7
# 19                20            3          5.7             2.7
# 20                20            3          5.7             2.7
# 21                20            3          5.7             2.7
# 22                20            3          5.7             2.7
# 23                20            3          5.7             2.7
# 24                20            3          5.7             2.7
# 25                20            3          5.7             2.7
# 26                20            3          5.7             2.7
# 27                20            3          5.7             2.7
# 28                20            3          5.7             2.7
# 29                20            3          5.7             2.7
# ...              ...          ...          ...             ...
# 18210             20            3          5.7             2.7
# 18211             20            3          5.7             2.7
# 18212             20            3          5.7             2.7
# 18213             20            3          5.7             2.7
# 18214             20            3          5.7             2.7
# 18215             20            3          5.7             2.7
# 18216             20            3          5.7             2.7
# 18217             20            3          5.7             2.7
# 18218             20            3          5.7             2.7
# 18219             20            3          5.7             2.7
# 18220             20            3          5.7             2.7
# 18221             20            3          5.7             2.7
# 18222             20            3          5.7             2.7
# 18223             20            3          5.7             2.7
# 18224             20            3          5.7             2.7
# 18225             20            3          5.7             2.7
# 18226             20            3          5.7             2.7
# 18227             20            3          5.7             2.7
# 18228             20            3          5.7             2.7
# 18229             20            3          5.7             2.7
# 18230             20            3          5.7             2.7
# 18231             20            3          5.7             2.7
# 18232             20            3          5.7             2.7
# 18233             20            3          5.7             2.7
# 18234             20            3          5.7             2.7
# 18235             20            3          5.7             2.7
# 18236             20            3          5.7             2.7
# 18237             20            3          5.7             2.7
# 18238             20            3          5.7             2.7
# 18239             20            3          5.7             2.7
#
#        dopant_percentage  triplet_ETL  total ETL
# 0                     10          2.9         35
# 1                     10          2.9         35
# 2                     10          2.9         35
# 3                     10          2.9         35
# 4                     10          2.9         35
# 5                     10          2.9         35
# 6                     10          2.9         35
# 7                     10          2.9         35
# 8                     10          2.9         35
# 9                     10          2.9         35
# 10                    10          2.9         35
# 11                    10          2.9         35
# 12                    10          2.9         35
# 13                    10          2.9         35
# 14                    10          2.9         35
# 15                    10          2.9         35
# 16                    10          2.9         35
# 17                    10          2.9         35
# 18                    10          2.9         35
# 19                    10          2.9         35
# 20                    10          2.9         35
# 21                    10          2.9         35
# 22                    10          2.9         35
# 23                    10          2.9         35
# 24                    10          2.9         35
# 25                    10          2.9         35
# 26                    10          2.9         35
# 27                    10          2.9         35
# 28                    10          2.9         35
# 29                    10          2.9         35
# ...                  ...          ...        ...
# 18210                 10          2.9         35
# 18211                 10          2.9         35
# 18212                 10          2.9         35
# 18213                 10          2.9         35
# 18214                 10          2.9         35
# 18215                 10          2.9         35
# 18216                 10          2.9         35
# 18217                 10          2.9         35
# 18218                 10          2.9         35
# 18219                 10          2.9         35
# 18220                 10          2.9         35
# 18221                 10          2.9         35
# 18222                 10          2.9         35
# 18223                 10          2.9         35
# 18224                 10          2.9         35
# 18225                 10          2.9         35
# 18226                 10          2.9         35
# 18227                 10          2.9         35
# 18228                 10          2.9         35
# 18229                 10          2.9         35
# 18230                 10          2.9         35
# 18231                 10          2.9         35
# 18232                 10          2.9         35
# 18233                 10          2.9         35
# 18234                 10          2.9         35
# 18235                 10          2.9         35
# 18236                 10          2.9         35
# 18237                 10          2.9         35
# 18238                 10          2.9         35
# 18239                 10          2.9         35
#
# [18240 rows x 12 columns]

# %%
new_X.lumo_ETL2.unique()
# Out:
# array([ 2.91,  3.32,  2.73,  2.5 ,  2.8 ,  2.6 ,  3.  ,  3.2 ,  2.7 ,
#         3.5 ,  2.88,  2.75,  3.47,  2.26,  2.52])

# %%
triplet3 = new_X.loc[new_X['HOMO_EML'] == 6.2]

column = 'cd/a'
device50 = triplet3.loc[triplet3[column] >= 50]
device45 = triplet3.loc[(triplet3[column] >= 45) & (new_X[column] < 50)]
device40 = triplet3.loc[(triplet3[column] >= 40) & (new_X[column] < 45)]
device35 = triplet3.loc[(triplet3[column] >= 35) & (new_X[column] < 40)]
device30 = triplet3.loc[(triplet3[column] >= 30) & (new_X[column] < 35)]
device25 = triplet3.loc[(triplet3[column] >= 25) & (new_X[column] < 30)]
device20 = triplet3.loc[(triplet3[column] >= 15) & (new_X[column] < 25)]
device10 = triplet3.loc[(triplet3[column] >= 10) & (new_X[column] < 15)]
device = triplet3.loc[triplet3[column] < 10]

# %%
def layer(name): 
    column = name
    HTL = {'50': device50[column], '45': device45[column] , '40': device40[column] , '35': device35[column] , 
           '30': device30[column] , '25': device25[column], '15': device20[column], '10': device10[column], 
           '0': device[column]}
    sequence = ['50', '45', '40', '35', '30', '25', '15', '10', '0']
    df = pd.DataFrame(data=HTL).reindex(columns=sequence)

    # boxplot
    f, ax = plt.subplots(figsize=(12, 10))
    fig = sns.boxplot(data=df)
    plt.xticks(rotation=90,fontsize=12)
    plt.yticks(fontsize=12)
    plt.title(name, fontsize=20);
    return df.describe()

layer('lumo_HTL1')
# Out:
#               50          45          40         35           30          25  \
# count  73.000000  570.000000  971.000000  89.000000  2649.000000  208.000000
# mean    2.287671    2.346842    2.210814   2.207865     2.279706    1.958462
# std     0.182380    0.134408    0.211574   0.214807     0.187026    0.074169
# min     1.900000    1.900000    1.900000   1.900000     1.900000    1.900000
# 25%     2.200000    2.260000    2.000000   2.000000     2.200000    1.900000
# 50%     2.400000    2.400000    2.260000   2.260000     2.400000    2.000000
# 75%     2.400000    2.400000    2.400000   2.400000     2.400000    2.000000
# max     2.500000    2.500000    2.500000   2.500000     2.500000    2.500000
#
#         15   10    0
# count  0.0  0.0  0.0
# mean   NaN  NaN  NaN
# std    NaN  NaN  NaN
# min    NaN  NaN  NaN
# 25%    NaN  NaN  NaN
# 50%    NaN  NaN  NaN
# 75%    NaN  NaN  NaN
# max    NaN  NaN  NaN

# %%
layer('homo_HTL1')
# Out:
#               50          45          40         35           30          25  \
# count  73.000000  570.000000  971.000000  89.000000  2649.000000  208.000000
# mean    5.754795    5.819123    5.657570   5.674157     5.736580    5.371635
# std     0.201412    0.167592    0.254591   0.330471     0.218814    0.256723
# min     5.100000    5.100000    5.100000   5.100000     5.100000    5.100000
# 25%     5.800000    5.800000    5.500000   5.500000     5.700000    5.100000
# 50%     5.800000    5.800000    5.800000   5.800000     5.800000    5.500000
# 75%     5.800000    5.800000    5.800000   5.800000     5.800000    5.500000
# max     6.100000    6.100000    6.100000   6.100000     6.100000    5.800000
#
#         15   10    0
# count  0.0  0.0  0.0
# mean   NaN  NaN  NaN
# std    NaN  NaN  NaN
# min    NaN  NaN  NaN
# 25%    NaN  NaN  NaN
# 50%    NaN  NaN  NaN
# 75%    NaN  NaN  NaN
# max    NaN  NaN  NaN

# %%
layer('lumo_ETL1')
# Out:
#                  50          45          40         35           30  \
# count  7.300000e+01  570.000000  971.000000  89.000000  2649.000000
# mean   3.470000e+00    2.747737    2.906962   3.381348     2.797852
# std    8.943251e-16    0.353213    0.305099   0.282176     0.301610
# min    3.470000e+00    2.260000    2.260000   2.500000     2.260000
# 25%    3.470000e+00    2.500000    2.730000   3.470000     2.600000
# 50%    3.470000e+00    2.700000    2.880000   3.470000     2.730000
# 75%    3.470000e+00    2.750000    3.200000   3.470000     2.910000
# max    3.470000e+00    3.500000    3.500000   3.500000     3.500000
#
#                25   15   10    0
# count  208.000000  0.0  0.0  0.0
# mean     2.852740  NaN  NaN  NaN
# std      0.200019  NaN  NaN  NaN
# min      2.260000  NaN  NaN  NaN
# 25%      2.730000  NaN  NaN  NaN
# 50%      2.880000  NaN  NaN  NaN
# 75%      2.910000  NaN  NaN  NaN
# max      3.320000  NaN  NaN  NaN

# %%
layer('homo_ETL1')
# Out:
#          50          45          40         35           30          25   15  \
# count  73.0  570.000000  971.000000  89.000000  2649.000000  208.000000  0.0
# mean    7.5    6.522351    6.535695   7.347079     6.472442    6.290433  NaN
# std     0.0    0.375179    0.443568   0.268685     0.342393    0.287708  NaN
# min     7.5    5.850000    5.850000   6.500000     5.850000    5.850000  NaN
# 25%     7.5    6.130000    6.130000   7.000000     6.130000    6.020000  NaN
# 50%     7.5    6.500000    6.500000   7.500000     6.500000    6.200000  NaN
# 75%     7.5    6.800000    6.790000   7.500000     6.790000    6.560000  NaN
# max     7.5    7.500000    7.500000   7.500000     7.000000    7.000000  NaN
#
#         10    0
# count  0.0  0.0
# mean   NaN  NaN
# std    NaN  NaN
# min    NaN  NaN
# 25%    NaN  NaN
# 50%    NaN  NaN
# 75%    NaN  NaN
# max    NaN  NaN

# %%
triplet3 = new_X.loc[new_X['HOMO_EML'] == 6]

column = 'cd/a'
device50 = triplet3.loc[triplet3[column] >= 50]
device45 = triplet3.loc[(triplet3[column] >= 45) & (new_X[column] < 50)]
device40 = triplet3.loc[(triplet3[column] >= 40) & (new_X[column] < 45)]
device35 = triplet3.loc[(triplet3[column] >= 35) & (new_X[column] < 40)]
device30 = triplet3.loc[(triplet3[column] >= 30) & (new_X[column] < 35)]
device25 = triplet3.loc[(triplet3[column] >= 25) & (new_X[column] < 30)]
device20 = triplet3.loc[(triplet3[column] >= 15) & (new_X[column] < 25)]
device10 = triplet3.loc[(triplet3[column] >= 10) & (new_X[column] < 15)]
device = triplet3.loc[triplet3[column] < 10]

# %%
layer('lumo_HTL1')
# Out:
#               50          45          40          35           30          25  \
# count  19.000000  523.000000  995.000000  159.000000  2385.000000  479.000000
# mean    2.395789    2.331625    2.218533    2.255346     2.297317    2.054489
# std     0.057185    0.147867    0.211492    0.198809     0.175293    0.188985
# min     2.260000    1.900000    1.900000    1.900000     1.900000    1.900000
# 25%     2.400000    2.260000    2.000000    2.100000     2.200000    1.900000
# 50%     2.400000    2.400000    2.260000    2.260000     2.400000    2.000000
# 75%     2.400000    2.400000    2.400000    2.400000     2.400000    2.200000
# max     2.500000    2.500000    2.500000    2.500000     2.500000    2.500000
#
#         15   10    0
# count  0.0  0.0  0.0
# mean   NaN  NaN  NaN
# std    NaN  NaN  NaN
# min    NaN  NaN  NaN
# 25%    NaN  NaN  NaN
# 50%    NaN  NaN  NaN
# 75%    NaN  NaN  NaN
# max    NaN  NaN  NaN

# %%
layer('homo_HTL1')
# Out:
#               50          45          40          35           30          25  \
# count  19.000000  523.000000  995.000000  159.000000  2385.000000  479.000000
# mean    5.873684    5.825430    5.653266    5.731447     5.761593    5.455115
# std     0.148482    0.162781    0.256067    0.260510     0.194947    0.282935
# min     5.700000    5.100000    5.100000    5.100000     5.100000    5.100000
# 25%     5.800000    5.800000    5.500000    5.700000     5.800000    5.100000
# 50%     5.800000    5.800000    5.800000    5.800000     5.800000    5.500000
# 75%     6.000000    5.800000    5.800000    5.800000     5.800000    5.800000
# max     6.100000    6.100000    6.100000    6.100000     6.100000    5.900000
#
#         15   10    0
# count  0.0  0.0  0.0
# mean   NaN  NaN  NaN
# std    NaN  NaN  NaN
# min    NaN  NaN  NaN
# 25%    NaN  NaN  NaN
# 50%    NaN  NaN  NaN
# 75%    NaN  NaN  NaN
# max    NaN  NaN  NaN

# %%
layer('lumo_ETL1')
# Out:
#                  50          45          40          35           30  \
# count  1.900000e+01  523.000000  995.000000  159.000000  2385.000000
# mean   3.470000e+00    2.774015    2.872613    3.400189     2.788021
# std    4.562583e-16    0.410791    0.265251    0.248350     0.309730
# min    3.470000e+00    2.260000    2.260000    2.500000     2.260000
# 25%    3.470000e+00    2.500000    2.715000    3.470000     2.520000
# 50%    3.470000e+00    2.700000    2.880000    3.470000     2.730000
# 75%    3.470000e+00    2.880000    3.000000    3.470000     2.910000
# max    3.470000e+00    3.500000    3.500000    3.500000     3.500000
#
#                25   15   10    0
# count  479.000000  0.0  0.0  0.0
# mean     2.887161  NaN  NaN  NaN
# std      0.213080  NaN  NaN  NaN
# min      2.260000  NaN  NaN  NaN
# 25%      2.750000  NaN  NaN  NaN
# 50%      2.880000  NaN  NaN  NaN
# 75%      3.000000  NaN  NaN  NaN
# max      3.320000  NaN  NaN  NaN

# %%
layer('homo_ETL1')
# Out:
#          50         45          40          35           30          25   15  \
# count  19.0  523.00000  995.000000  159.000000  2385.000000  479.000000  0.0
# mean    7.5    6.60956    6.466935    7.430755     6.483132    6.349770  NaN
# std     0.0    0.47880    0.350955    0.212753     0.344566    0.311909  NaN
# min     7.5    5.85000    5.850000    6.500000     5.850000    5.850000  NaN
# 25%     7.5    6.20000    6.130000    7.500000     6.130000    6.020000  NaN
# 50%     7.5    6.68000    6.500000    7.500000     6.500000    6.400000  NaN
# 75%     7.5    6.80000    6.680000    7.500000     6.790000    6.560000  NaN
# max     7.5    7.50000    7.500000    7.500000     7.000000    7.000000  NaN
#
#         10    0
# count  0.0  0.0
# mean   NaN  NaN
# std    NaN  NaN
# min    NaN  NaN
# 25%    NaN  NaN
# 50%    NaN  NaN
# 75%    NaN  NaN
# max    NaN  NaN

# %%
triplet3 = new_X.loc[new_X['HOMO_EML'] == 5.8]

column = 'cd/a'
device50 = triplet3.loc[triplet3[column] >= 50]
device45 = triplet3.loc[(triplet3[column] >= 45) & (new_X[column] < 50)]
device40 = triplet3.loc[(triplet3[column] >= 40) & (new_X[column] < 45)]
device35 = triplet3.loc[(triplet3[column] >= 35) & (new_X[column] < 40)]
device30 = triplet3.loc[(triplet3[column] >= 30) & (new_X[column] < 35)]
device25 = triplet3.loc[(triplet3[column] >= 25) & (new_X[column] < 30)]
device20 = triplet3.loc[(triplet3[column] >= 15) & (new_X[column] < 25)]
device10 = triplet3.loc[(triplet3[column] >= 10) & (new_X[column] < 15)]
device = triplet3.loc[triplet3[column] < 10]

# %% [markdown]
# layer('lumo_HTL1')

# %%
layer('homo_HTL1')
# Out:
#               50          45           40          35           30  \
# count  11.000000  414.000000  1151.000000  160.000000  2413.000000
# mean    5.936364    5.828502     5.675326    5.768750     5.754414
# std     0.162928    0.171757     0.248227    0.285099     0.196661
# min     5.700000    5.100000     5.100000    5.100000     5.100000
# 25%     5.800000    5.800000     5.700000    5.700000     5.800000
# 50%     5.900000    5.800000     5.800000    5.800000     5.800000
# 75%     6.100000    5.900000     5.800000    5.900000     5.800000
# max     6.100000    6.100000     6.100000    6.100000     6.100000
#
#                25   15   10    0
# count  411.000000  0.0  0.0  0.0
# mean     5.425791  NaN  NaN  NaN
# std      0.276858  NaN  NaN  NaN
# min      5.100000  NaN  NaN  NaN
# 25%      5.100000  NaN  NaN  NaN
# 50%      5.500000  NaN  NaN  NaN
# 75%      5.700000  NaN  NaN  NaN
# max      5.900000  NaN  NaN  NaN

# %%
layer('lumo_ETL1')
# Out:
#                  50          45           40          35           30  \
# count  1.100000e+01  414.000000  1151.000000  160.000000  2413.000000
# mean   3.470000e+00    2.846739     2.861512    3.216625     2.792114
# std    9.315294e-16    0.451971     0.287560    0.427367     0.305917
# min    3.470000e+00    2.260000     2.260000    2.260000     2.260000
# 25%    3.470000e+00    2.500000     2.700000    2.600000     2.600000
# 50%    3.470000e+00    2.700000     2.800000    3.470000     2.730000
# 75%    3.470000e+00    3.470000     3.000000    3.470000     2.910000
# max    3.470000e+00    3.500000     3.500000    3.500000     3.500000
#
#                25   15   10    0
# count  411.000000  0.0  0.0  0.0
# mean     2.884793  NaN  NaN  NaN
# std      0.211018  NaN  NaN  NaN
# min      2.260000  NaN  NaN  NaN
# 25%      2.750000  NaN  NaN  NaN
# 50%      2.880000  NaN  NaN  NaN
# 75%      3.000000  NaN  NaN  NaN
# max      3.320000  NaN  NaN  NaN

# %%
layer('homo_ETL1')
# Out:
#          50          45           40          35           30          25  \
# count  11.0  414.000000  1151.000000  160.000000  2413.000000  411.000000
# mean    7.5    6.702609     6.489157    7.238125     6.478114    6.333358
# std     0.0    0.497601     0.392397    0.390093     0.343221    0.307849
# min     7.5    5.850000     5.850000    5.850000     5.850000    5.850000
# 25%     7.5    6.500000     6.130000    6.800000     6.130000    6.020000
# 50%     7.5    6.790000     6.500000    7.500000     6.500000    6.300000
# 75%     7.5    7.000000     6.790000    7.500000     6.790000    6.560000
# max     7.5    7.500000     7.500000    7.500000     7.000000    7.000000
#
#         15   10    0
# count  0.0  0.0  0.0
# mean   NaN  NaN  NaN
# std    NaN  NaN  NaN
# min    NaN  NaN  NaN
# 25%    NaN  NaN  NaN
# 50%    NaN  NaN  NaN
# 75%    NaN  NaN  NaN
# max    NaN  NaN  NaN

# %%
triplet3 = new_X.loc[new_X['HOMO_EML'] == 5.6]

column = 'cd/a'
device50 = triplet3.loc[triplet3[column] >= 50]
device45 = triplet3.loc[(triplet3[column] >= 45) & (new_X[column] < 50)]
device40 = triplet3.loc[(triplet3[column] >= 40) & (new_X[column] < 45)]
device35 = triplet3.loc[(triplet3[column] >= 35) & (new_X[column] < 40)]
device30 = triplet3.loc[(triplet3[column] >= 30) & (new_X[column] < 35)]
device25 = triplet3.loc[(triplet3[column] >= 25) & (new_X[column] < 30)]
device20 = triplet3.loc[(triplet3[column] >= 15) & (new_X[column] < 25)]
device10 = triplet3.loc[(triplet3[column] >= 10) & (new_X[column] < 15)]
device = triplet3.loc[triplet3[column] < 10]

# %%
layer('lumo_HTL1')
# Out:
#               50          45           40          35           30  \
# count  21.000000  426.000000  1154.000000  221.000000  2406.000000
# mean    2.396190    2.367371     2.220607    2.324253     2.283924
# std     0.054266    0.120786     0.206211    0.175390     0.182513
# min     2.260000    1.900000     1.900000    1.900000     1.900000
# 25%     2.400000    2.400000     2.000000    2.260000     2.200000
# 50%     2.400000    2.400000     2.260000    2.400000     2.400000
# 75%     2.400000    2.400000     2.400000    2.400000     2.400000
# max     2.500000    2.500000     2.500000    2.500000     2.500000
#
#                25   15   10    0
# count  332.000000  0.0  0.0  0.0
# mean     2.000060  NaN  NaN  NaN
# std      0.143554  NaN  NaN  NaN
# min      1.900000  NaN  NaN  NaN
# 25%      1.900000  NaN  NaN  NaN
# 50%      2.000000  NaN  NaN  NaN
# 75%      2.000000  NaN  NaN  NaN
# max      2.500000  NaN  NaN  NaN

# %%
layer('homo_HTL1')
# Out:
#               50          45           40          35           30  \
# count  21.000000  426.000000  1154.000000  221.000000  2406.000000
# mean    5.866667    5.833099     5.672964    5.809502     5.742269
# std     0.146059    0.167777     0.247444    0.255752     0.205204
# min     5.700000    5.100000     5.100000    5.100000     5.100000
# 25%     5.800000    5.800000     5.700000    5.800000     5.700000
# 50%     5.800000    5.800000     5.800000    5.800000     5.800000
# 75%     5.900000    5.900000     5.800000    6.100000     5.800000
# max     6.100000    6.100000     6.100000    6.100000     6.100000
#
#                25   15   10    0
# count  332.000000  0.0  0.0  0.0
# mean     5.405120  NaN  NaN  NaN
# std      0.271848  NaN  NaN  NaN
# min      5.100000  NaN  NaN  NaN
# 25%      5.100000  NaN  NaN  NaN
# 50%      5.500000  NaN  NaN  NaN
# 75%      5.500000  NaN  NaN  NaN
# max      5.800000  NaN  NaN  NaN

# %%
layer('lumo_ETL1')
# Out:
#                  50          45           40          35           30  \
# count  2.100000e+01  426.000000  1154.000000  221.000000  2406.000000
# mean   3.470000e+00    2.821315     2.878960    3.000905     2.797893
# std    4.550560e-16    0.424624     0.305253    0.468215     0.299414
# min    3.470000e+00    2.260000     2.260000    2.260000     2.260000
# 25%    3.470000e+00    2.500000     2.700000    2.500000     2.600000
# 50%    3.470000e+00    2.700000     2.800000    2.750000     2.730000
# 75%    3.470000e+00    3.470000     3.000000    3.470000     2.910000
# max    3.470000e+00    3.500000     3.500000    3.500000     3.500000
#
#                25   15   10    0
# count  332.000000  0.0  0.0  0.0
# mean     2.879518  NaN  NaN  NaN
# std      0.231988  NaN  NaN  NaN
# min      2.260000  NaN  NaN  NaN
# 25%      2.730000  NaN  NaN  NaN
# 50%      2.880000  NaN  NaN  NaN
# 75%      3.000000  NaN  NaN  NaN
# max      3.320000  NaN  NaN  NaN

# %%
layer('homo_ETL1')
# Out:
#          50          45           40          35           30          25  \
# count  21.0  426.000000  1154.000000  221.000000  2406.000000  332.000000
# mean    7.5    6.651808     6.518830    6.992534     6.461509    6.366145
# std     0.0    0.483115     0.418607    0.432829     0.344169    0.314361
# min     7.5    5.850000     5.850000    5.850000     5.850000    5.850000
# 25%     7.5    6.300000     6.130000    6.790000     6.130000    6.020000
# 50%     7.5    6.680000     6.500000    6.800000     6.500000    6.400000
# 75%     7.5    7.000000     6.790000    7.500000     6.790000    6.670000
# max     7.5    7.500000     7.500000    7.500000     7.000000    7.000000
#
#         15   10    0
# count  0.0  0.0  0.0
# mean   NaN  NaN  NaN
# std    NaN  NaN  NaN
# min    NaN  NaN  NaN
# 25%    NaN  NaN  NaN
# 50%    NaN  NaN  NaN
# 75%    NaN  NaN  NaN
# max    NaN  NaN  NaN

# %%
triplet3 = new_X.loc[new_X['HOMO_EML'] == 5.6]
triplet3 = triplet3[['homo_HTL1', 'homo_ETL1', 'cd/a']]

triplet3.shape

triplet3.to_csv('C:/Anaconda3/projects/oled/fix all triplets/homo56.csv', header=triplet3.columns, 
             index=None, sep=',')
