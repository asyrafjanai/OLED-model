# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_val_score
import pickle

df = pd.read_excel('C:/Anaconda3/projects/oled/oled.xlsx', sheetname='pholed_model')
df = df[list(df.columns)[1:-1] + ['cd/A']]
df.dropna(axis=0, inplace=True)

X = df[list(df.columns)[:-1]]
y = df[['cd/A']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25, random_state=12)

# filename = 'adaboost_model.sav'
filename = 'pholed_rf_model.sav'

# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
print('R-squared: ', loaded_model.score(X_test, y_test))
# Out:
# R-squared:  0.87869391923

# %%
df1 = pd.read_pickle('C:/Anaconda3/projects/oled/firpic sppo13/45.pkl')
df2 = pd.read_pickle('C:/Anaconda3/projects/oled/firpic sppo13/40.pkl')
df3 = pd.read_pickle('C:/Anaconda3/projects/oled/firpic sppo13/35.pkl')
df4 = pd.read_pickle('C:/Anaconda3/projects/oled/firpic sppo13/30.pkl')
df5 = pd.read_pickle('C:/Anaconda3/projects/oled/firpic sppo13/25.pkl')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

HTL = {'45': df1['lumo_HTL1'] , '40': df2['lumo_HTL1'] , '35': df3['lumo_HTL1'] , 
       '30': df4['lumo_HTL1'] , '25': df5['lumo_HTL1'] }
sequence = ['45', '40', '35', '30', '25']
df = pd.DataFrame(data=HTL).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=12)
plt.title('HTL LUMO ',fontsize=20);
df.describe()
# Out:
#                  45          40   35          30          25
# count  3.200000e+01  647.000000  9.0  909.000000  442.000000
# mean   2.400000e+00    2.250232  2.4    2.317866    2.130452
# std    4.511951e-16    0.201594  0.0    0.131730    0.249851
# min    2.400000e+00    1.900000  2.4    1.900000    1.900000
# 25%    2.400000e+00    2.000000  2.4    2.260000    1.900000
# 50%    2.400000e+00    2.260000  2.4    2.400000    2.000000
# 75%    2.400000e+00    2.400000  2.4    2.400000    2.500000
# max    2.400000e+00    2.500000  2.4    2.500000    2.500000

# %%
HTL = {'45': df1['homo_HTL1'] , '40': df2['homo_HTL1'] , '35': df3['homo_HTL1'] , 
       '30': df4['homo_HTL1'] , '25': df5['homo_HTL1'] }
sequence = ['45', '40', '35', '30', '25']
df = pd.DataFrame(data=HTL).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=12)
plt.title('HTL homo ',fontsize=20);
df.describe()
# Out:
#                  45          40            35          30         25
# count  3.200000e+01  647.000000  9.000000e+00  909.000000  442.00000
# mean   6.100000e+00    5.600773  6.100000e+00    5.771287    5.31448
# std    2.707171e-15    0.308421  9.420555e-16    0.236672    0.23127
# min    6.100000e+00    5.100000  6.100000e+00    5.100000    5.10000
# 25%    6.100000e+00    5.200000  6.100000e+00    5.700000    5.10000
# 50%    6.100000e+00    5.700000  6.100000e+00    5.800000    5.20000
# 75%    6.100000e+00    5.800000  6.100000e+00    5.900000    5.50000
# max    6.100000e+00    6.100000  6.100000e+00    6.100000    5.90000

# %%
HTL = {'45': df1['triplet_HTL'] , '40': df2['triplet_HTL'] , '35': df3['triplet_HTL'] , 
       '30': df4['triplet_HTL'] , '25': df5['triplet_HTL'] }
sequence = ['45', '40', '35', '30', '25']
df = pd.DataFrame(data=HTL).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=12)
plt.title('HTL triplet ',fontsize=20);
df.describe()
# Out:
#                  45          40            35          30          25
# count  3.200000e+01  647.000000  9.000000e+00  909.000000  442.000000
# mean   2.800000e+00    2.760587  2.800000e+00    2.819571    2.644367
# std    1.353585e-15    0.225825  4.710277e-16    0.193649    0.227347
# min    2.800000e+00    2.300000  2.800000e+00    2.300000    2.300000
# 25%    2.800000e+00    2.580000  2.800000e+00    2.800000    2.300000
# 50%    2.800000e+00    2.870000  2.800000e+00    2.940000    2.670000
# 75%    2.800000e+00    2.940000  2.800000e+00    2.940000    2.870000
# max    2.800000e+00    3.000000  2.800000e+00    3.000000    3.000000

# %%
EML = {'45': df1['LUMO_EML'] , '40': df2['LUMO_EML'] , '35': df3['LUMO_EML'] , 
       '30': df4['LUMO_EML'] , '25': df5['LUMO_EML'] }
sequence = ['45', '40', '35', '30', '25']
df = pd.DataFrame(data=EML).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=12)
plt.title('EML lumo ',fontsize=20);
df.describe()
# Out:
#               45          40        35          30          25
# count  32.000000  647.000000  9.000000  909.000000  442.000000
# mean    2.415625    2.419598  2.442222    2.425677    2.404253
# std     0.205127    0.252807  0.053333    0.258868    0.235656
# min     2.240000    2.020000  2.300000    2.020000    2.020000
# 25%     2.300000    2.280000  2.460000    2.280000    2.270000
# 50%     2.300000    2.400000  2.460000    2.400000    2.400000
# 75%     2.460000    2.460000  2.460000    2.460000    2.460000
# max     3.000000    3.000000  2.460000    3.000000    3.000000

# %%
EML = {'45': df1['HOMO_EML'] , '40': df2['HOMO_EML'] , '35': df3['HOMO_EML'] , 
       '30': df4['HOMO_EML'] , '25': df5['HOMO_EML'] }
sequence = ['45', '40', '35', '30', '25']
df = pd.DataFrame(data=EML).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=12)
plt.title('EML homo ',fontsize=20);
df.describe()
# Out:
#               45          40        35          30          25
# count  32.000000  647.000000  9.000000  909.000000  442.000000
# mean    5.798438    5.913586  5.714444    5.844873    6.040679
# std     0.090237    0.426684  0.032447    0.299633    0.570452
# min     5.700000    5.560000  5.700000    5.560000    5.560000
# 25%     5.710000    5.710000  5.700000    5.700000    5.800000
# 50%     5.800000    5.850000  5.700000    5.800000    5.900000
# 75%     5.860000    5.900000  5.710000    5.900000    5.920000
# max     6.060000    7.500000  5.800000    7.500000    7.500000

# %%
EML = {'45': df1['triplet_HOST'] , '40': df2['triplet_HOST'] , '35': df3['triplet_HOST'] , 
       '30': df4['triplet_HOST'] , '25': df5['triplet_HOST'] }
sequence = ['45', '40', '35', '30', '25']
df = pd.DataFrame(data=EML).reindex(columns=sequence)

# boxplot
f, ax = plt.subplots(figsize=(12, 10))
fig = sns.boxplot(data=df)
plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=12)
plt.title('EML triplet host ',fontsize=20);
df.describe()
# Out:
#               45          40        35          30          25
# count  32.000000  647.000000  9.000000  909.000000  442.000000
# mean    2.990937    2.904869  2.957778    2.925765    2.872986
# std     0.084714    0.107274  0.053333    0.098998    0.116664
# min     2.790000    2.640000  2.940000    2.640000    2.640000
# 25%     2.940000    2.860000  2.940000    2.900000    2.800000
# 50%     2.940000    2.910000  2.940000    2.930000    2.900000
# 75%     3.100000    2.940000  2.940000    2.940000    2.930000
# max     3.100000    3.100000  3.100000    3.100000    3.100000
